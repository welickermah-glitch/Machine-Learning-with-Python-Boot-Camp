# %% [markdown]
# <a href="https://colab.research.google.com/github/welickermah-glitch/Machine-Learning-with-Python-Boot-Camp/blob/main/Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# Create a labeled storage basket and put a number inside
tomato_price = 150
pepper_price = 80

# Pull the value out of the baskets
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables(ML Anchor)

# %%
#--- THE CLUES (Features group as X)
rainfall_mm = 45.2     # Clue 1
bags_available = 100   # Clue 2

#--- THE GOAL (Target labeled as y) ---
predicted_price = 3200 # What our AI calculates

print("Inputs (X):", rainfall_mm, "mm rain,", bags_available, "bags.")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Inputs (X): 45.2 mm rain, 100 bags.
# Output (y): 3200 LRD.

# %% [markdown]
# Understanding Variables

# %%
Liberia = 1847
print(Liberia) #valuewillappear
print("Liberia") #textwillappear
# Out:
# 1847
# Liberia

# %% [markdown]
# Understanding Print Statement

# %%
plum= 50
print("Plum previous price was:" ,plum)
plum= 80
print("plum new price is:", plum)
# Out:
# Plum previous price was: 50
# plum new price is: 80

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open = True

print(type(quantity)) #
print(type(price)) #
print(type(item_name)) #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
